# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader(web_url="https://maths.du.ac.in/faculty-profile/")
docs = loader.load()

# %%
full_doc = "\n\n".join(doc.page_content for doc in docs)
print(full_doc)
# Out:
# DU
#
#
#
#
#
# Menu Close
#
# Home
#
# About
#
# Welcome
#
# History
#
# Campus
#
# Seminar & Lecture Rooms
#
# Research Scholar Room
#
# Computer Lab
#
# Committee Room
#
# Library
#
# Disabled-Friendly Campus
#
# Clean and Green Campus
#
# Ranking
#
# Committees
#
# Accomplishments
#
# Department
#
# Faculty
#
# Students
#
# Annual Reports
#
# Gallery
#
# Redressal Mechanisms
#
# Brochure
#
# Contact Us
#
# People
#
# Faculty Profile
#
# Post-Doc Fellows
#
# Ph.D. Scholars
#
# M.Phil. Scholars
#
# Supporting Staff
#
# Tutors
#
# Former Faculty
#
# Former HODs
#
# Research
#
# Research Areas
#
# Publications
#
# Books Authored
#
# Research Grants
#
# Collaborations
#
# Research Supervision
#
# M.Phil. Awarded
#
# Ph.D. Awarded
#
# Academics
#
# M.Sc. Programme
#
# Ph.D. Programme
#
# U.G. Curriculum
#
# Academic Calendar
#
# Time Tables
#
# Examination and Results
#
# Admissions
#
# M.Sc. Admissions
#
# Ph.D. Admissions
#
# Resources
#
# Library@DU
#
# Forms
#
# Useful Links
#
# ...

# %%
question = "Return a list of all email address, with a serial number, ordered alphabetically."

prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question}
Context: {context}
Answer:"""

from langchain.chat_models import init_chat_model
llm = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

response = llm.invoke(prompt_template.format(
    context=full_doc,
    question=question))

from IPython.display import Markdown
Markdown(response.content)
# Out:
# INFO: HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Here is the list of email addresses with a serial number, ordered alphabetically:
# 1. ag.nikita@gmail.com
# 2. akumar@maths.du.ac.in
# 3. anuj.bshn@gmail.com
# 4. arvindpatelmath09@gmail.com
# 5. ashrsdma@gmail.com
# 6. azothansanga26@yahoo.com
# 7. cslalitha1@gmail.com
# 8. hemantksingh@maths.du.ac.in
# 9. lalit@maths.du.ac.in
# 10. lkumarvashisht@gmail.com
# 11. moghadma@gmail.com
# 12. rkpanda@maths.du.ac.in
# 13. rjain@maths.du.ac.in
# 14. rdasmsu@gmail.com
# 15. sachinambariya@gmail.com
# 16. sachi_srivastava@yahoo.com
# 17. ssrivastava@maths.du.ac.in
# 18. sumitnagpal.du@gmail.com
# 19. surendraiitr8@gmail.com
# 20. tarukd@gmail.com
# 21. vambethkar@gmail.com
# 22. vambethkar@maths.du.ac.in.

# %%
question = """Extract the names, designation, for each professor and return in this format
**Name** *emailID* as a list"""

prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question}
Context: {context}
Answer:"""

response = llm.invoke(prompt_template.format(
    context=full_doc,
    question=question))

from IPython.display import Markdown
Markdown(response.content)
# Out:
# INFO: HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Here is the list of professors in the requested format:
# * **Prof. Tarun Kumar Das** *tarukd@gmail.com*
# * **Prof. C.S. Lalitha** *cslalitha1@gmail.com*
# * **Prof. Ruchi Das** *rdasmsu@gmail.com*
# * **Prof. Vusala Ambethkar** *vambethkar@gmail.com, vambethkar@maths.du.ac.in*
# * **Prof. Sachi Srivastava** *sachi_srivastava@yahoo.com, ssrivastava@maths.du.ac.in*
# * **Prof. Lalit Kumar** *lalit@maths.du.ac.in, lkumarvashisht@gmail.com*
# * **Prof. Arvind Patel** *arvindpatelmath09@gmail.com*
# * **Prof. Atul Gaur** *agaur@maths.du.ac.in*
# * **Prof. Hemant Kumar Singh** *hemantksingh@maths.du.ac.in*
# * **Prof. Ranjana Jain** *rjain@maths.du.ac.in*
# * **Prof. Sachin Kumar** *sachinambariya@gmail.com*
# * **Prof. Nikita Agarwal** *ag.nikita@gmail.com*
# * **Dr. A. Zothansanga** *azothansanga26@yahoo.com*
# * **Dr. Anupama Panigrahi** *anupama.panigrahi@gmail.com*
# ...

# %%
loader2 = UnstructuredLoader(web_url="https://www.formula1.com/en/results/2025/drivers")
docs2 = loader2.load()
full_doc2 = "\n\n".join(doc.page_content for doc in docs2)
print(full_doc2)
# Out:
# RacesDriversTeamsAwards
#
# 2025 Drivers' Standings
#
# POS. DRIVER NATIONALITY TEAM PTS. 1 Oscar Piastri PIA AUS McLaren 324 2 Lando Norris NOR GBR McLaren 293 3 Max Verstappen VER NED Red Bull Racing 230 4 George Russell RUS GBR Mercedes 194 5 Charles Leclerc LEC MON Ferrari 163 6 Lewis Hamilton HAM GBR Ferrari 117 7 Alexander Albon ALB THA Williams 70 8 Kimi Antonelli ANT ITA Mercedes 66 9 Isack Hadjar HAD FRA Racing Bulls 38 10 Nico Hulkenberg HUL GER Kick Sauber 37 11 Lance Stroll STR CAN Aston Martin 32 12 Fernando Alonso ALO ESP Aston Martin 30 13 Esteban Ocon OCO FRA Haas 28 14 Pierre Gasly GAS FRA Alpine 20 15 Liam Lawson LAW NZL Racing Bulls 20 16 Gabriel Bortoleto BOR BRA Kick Sauber 18 17 Oliver Bearman BEA GBR Haas 16 18 Carlos Sainz SAI ESP Williams 16 19 Yuki Tsunoda TSU JPN Red Bull Racing 12 20 Franco Colapinto COL ARG Alpine 0 21 Jack Doohan DOO AUS Alpine 0

# %%
question = """Extract the names, position, team, for each driver and return in this format
**Name** in bold -- *Position* -- *Team* as a list, with column headers separated by dashes.
Question: {question}
Context: {context}"""

prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question}
Context: {context}
Answer:"""

response = llm.invoke(prompt_template.format(
    context=full_doc2,
    question=question))

from IPython.display import Markdown
Markdown(response.content)
# Out:
# INFO: HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Name - Position - Team
# * **Oscar Piastri** -- 1 -- *McLaren*
# * **Lando Norris** -- 2 -- *McLaren*
# * **Max Verstappen** -- 3 -- *Red Bull Racing*
# * **George Russell** -- 4 -- *Mercedes*
# * **Charles Leclerc** -- 5 -- *Ferrari*
# * **Lewis Hamilton** -- 6 -- *Ferrari*
# * **Alexander Albon** -- 7 -- *Williams*
# * **Kimi Antonelli** -- 8 -- *Mercedes*
# * **Isack Hadjar** -- 9 -- *Racing Bulls*
# * **Nico Hulkenberg** -- 10 -- *Kick Sauber*
# * **Lance Stroll** -- 11 -- *Aston Martin*
# * **Fernando Alonso** -- 12 -- *Aston Martin*
# * **Esteban Ocon** -- 13 -- *Haas*
# * **Pierre Gasly** -- 14 -- *Alpine*
# * **Liam Lawson** -- 15 -- *Racing Bulls*
# * **Gabriel Bortoleto** -- 16 -- *Kick Sauber*
# * **Oliver Bearman** -- 17 -- *Haas*
# * **Carlos Sainz** -- 18 -- *Williams*
# * **Yuki Tsunoda** -- 19 -- *Red Bull Racing*
# * **Franco Colapinto** -- 20 -- *Alpine*
# ...
